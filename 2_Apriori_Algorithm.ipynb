# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from apyori import apriori

# %%
df = pd.read_csv("Stationery.csv")

# %%
df.head()
# Out:
#    ID    Name     Item1      Item2      Item3  Item4  Bill
# 0   1  Tushar    Pencil     Eraser   Sharpner    NaN    20
# 1   2  Ramesh       Pen      Pages      Files    Gum    65
# 2   3  Pankaj    Eraser    Perfume  Chocolate    NaN    40
# 3   4  Kartik     Pages      Files    Stapler  Scale   110
# 4   5  Ganesh  Biscuits  Chocolate        NaN    NaN    15

# %%
df.isnull().sum()
# Out:
# ID        0
# Name      0
# Item1     0
# Item2     2
# Item3     6
# Item4    16
# Bill      0
# dtype: int64

# %%
df1 = df[['Item1','Item2','Item3','Item4']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      23 non-null     int64
#  1   Name    23 non-null     object
#  2   Item1   23 non-null     object
#  3   Item2   21 non-null     object
#  4   Item3   17 non-null     object
#  5   Item4   7 non-null      object
#  6   Bill    23 non-null     int64
# dtypes: int64(2), object(5)
# memory usage: 1.4+ KB

# %%
df1.head()
# Out:
#       Item1      Item2      Item3  Item4
# 0    Pencil     Eraser   Sharpner    NaN
# 1       Pen      Pages      Files    Gum
# 2    Eraser    Perfume  Chocolate    NaN
# 3     Pages      Files    Stapler  Scale
# 4  Biscuits  Chocolate        NaN    NaN

# %%
records = []
for i in range(23):
    records.append([str(df1.values[i, j]) for j in range(0, 4)])

# %%
print(type(records))
# Out:
# <class 'list'>

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
for i in range(0, len(association_results)):
    print(association_results[i][0])
# Out:
# frozenset({'Sharpner', 'Eraser'})
# frozenset({'Stapler', 'Files'})
# frozenset({'Gum', 'Scale'})
# frozenset({'Gum', 'Sheets'})
# frozenset({'Pages', 'Stapler'})
# frozenset({'Sharpner', 'Pencil'})
# frozenset({'Scale', 'Stapler'})
# frozenset({'Biscuits', 'Pencil', 'Chocolate'})
# frozenset({'Biscuits', 'Scale', 'Chocolate'})
# frozenset({'Biscuits', 'nan', 'Chocolate'})
# frozenset({'Compass', 'Files', 'Chocolate'})
# frozenset({'Perfume', 'Eraser', 'Chocolate'})
# frozenset({'Compass', 'Pages', 'Files'})
# frozenset({'Compass', 'Pen', 'Files'})
# frozenset({'Compass', 'Scale', 'Gum'})
# frozenset({'Compass', 'Sheets', 'Gum'})
# frozenset({'Compass', 'Scale', 'Sheets'})
# frozenset({'Eraser', 'Pencil', 'Pen'})
# frozenset({'Sharpner', 'Eraser', 'Pen'})
# frozenset({'Sharpner', 'Eraser', 'Pencil'})
# frozenset({'Perfume', 'Eraser', 'nan'})
# frozenset({'Sharpner', 'Eraser', 'nan'})
# frozenset({'Gum', 'Pages', 'Files'})
# frozenset({'Gum', 'Pen', 'Files'})
# frozenset({'Gum', 'Scale', 'Files'})
# frozenset({'Gum', 'nan', 'Files'})
# frozenset({'Pages', 'Pen', 'Files'})
# frozenset({'Pages', 'Pencil', 'Files'})
# frozenset({'Scale', 'Pages', 'Files'})
# frozenset({'Pages', 'Stapler', 'Files'})
# frozenset({'Scale', 'Stapler', 'Files'})
# frozenset({'Gum', 'Pages', 'Pen'})
# frozenset({'Gum', 'Scale', 'Sheets'})
# frozenset({'Gum', 'Scale', 'nan'})
# frozenset({'Perfume', 'Pages', 'Notebook'})
# frozenset({'nan', 'Notebook', 'Pen'})
# frozenset({'Sheets', 'nan', 'Notebook'})
# frozenset({'Perfume', 'Pages', 'nan'})
# frozenset({'Scale', 'Pages', 'Stapler'})
# frozenset({'Scale', 'Pencil', 'Pen'})
# frozenset({'Sharpner', 'Pencil', 'Pen'})
# frozenset({'Sharpner', 'nan', 'Pencil'})
# frozenset({'Biscuits', 'nan', 'Pencil', 'Chocolate'})
# frozenset({'Biscuits', 'Scale', 'nan', 'Chocolate'})
# frozenset({'Compass', 'Files', 'Pen', 'Chocolate'})
# frozenset({'Perfume', 'Eraser', 'nan', 'Chocolate'})
# frozenset({'nan', 'Notebook', 'Pen', 'Chocolate'})
# frozenset({'Compass', 'Pages', 'nan', 'Files'})
# frozenset({'Compass', 'Scale', 'Gum', 'Sheets'})
# frozenset({'Sharpner', 'Eraser', 'Pencil', 'Pen'})
# frozenset({'Sharpner', 'Eraser', 'nan', 'Pencil'})
# frozenset({'Gum', 'Pages', 'Pen', 'Files'})
# frozenset({'Gum', 'Scale', 'nan', 'Files'})
# frozenset({'Pages', 'Pencil', 'Pen', 'Files'})
# frozenset({'Scale', 'Pages', 'Stapler', 'Files'})
# frozenset({'Perfume', 'Pages', 'nan', 'Notebook'})
# frozenset({'nan', 'Pencil', 'Notebook', 'Pen'})
# frozenset({'Scale', 'nan', 'Pencil', 'Pen'})

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    # second index of the inner list
    print("Support: " + str(item[1]))

    # third index of the list located at 0th
    # of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: Sharpner -> Eraser
# Support: 0.13043478260869565
# Confidence: 0.75
# Lift: 5.75
# =====================================
# Rule: Stapler -> Files
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Gum -> Scale
# Support: 0.08695652173913043
# Confidence: 0.6666666666666666
# Lift: 3.0666666666666664
# =====================================
# Rule: Gum -> Sheets
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 3.833333333333333
# =====================================
# Rule: Pages -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Sharpner -> Pencil
# Support: 0.13043478260869565
# Confidence: 0.42857142857142855
# Lift: 3.2857142857142856
# =====================================
# Rule: Scale -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Biscuits -> Pencil
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Biscuits -> Scale
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Biscuits -> nan
# Support: 0.21739130434782608
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Compass -> Files
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Perfume -> Eraser
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Compass -> Pages
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Compass -> Pen
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Compass -> Scale
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 7.666666666666666
# =====================================
# Rule: Compass -> Sheets
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Compass -> Scale
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Eraser -> Pencil
# Support: 0.08695652173913043
# Confidence: 0.2857142857142857
# Lift: 3.2857142857142856
# =====================================
# Rule: Sharpner -> Eraser
# Support: 0.08695652173913043
# Confidence: 0.5
# Lift: 5.75
# =====================================
# Rule: Sharpner -> Eraser
# Support: 0.13043478260869565
# Confidence: 0.75
# Lift: 5.75
# =====================================
# Rule: Perfume -> Eraser
# Support: 0.043478260869565216
# Confidence: 0.5
# Lift: 5.75
# =====================================
# Rule: Sharpner -> Eraser
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Gum -> Pages
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Gum -> Pen
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Gum -> Scale
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 3.833333333333333
# =====================================
# Rule: Gum -> nan
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Pages -> Pen
# Support: 0.08695652173913043
# Confidence: 0.2857142857142857
# Lift: 3.2857142857142856
# =====================================
# Rule: Pages -> Pencil
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Scale -> Pages
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Pages -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Scale -> Stapler
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Gum -> Pages
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 3.833333333333333
# =====================================
# Rule: Gum -> Scale
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 7.666666666666666
# =====================================
# Rule: Gum -> Scale
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Perfume -> Pages
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: nan -> Notebook
# Support: 0.08695652173913043
# Confidence: 0.5
# Lift: 3.8333333333333335
# =====================================
# Rule: Sheets -> nan
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Perfume -> Pages
# Support: 0.043478260869565216
# Confidence: 0.5
# Lift: 5.75
# =====================================
# Rule: Scale -> Pages
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Scale -> Pencil
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Sharpner -> Pencil
# Support: 0.08695652173913043
# Confidence: 0.2857142857142857
# Lift: 3.2857142857142856
# =====================================
# Rule: Sharpner -> nan
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 3.2857142857142856
# =====================================
# Rule: Biscuits -> nan
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Biscuits -> Scale
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Compass -> Files
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Perfume -> Eraser
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: nan -> Notebook
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Compass -> Pages
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Compass -> Scale
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Sharpner -> Eraser
# Support: 0.08695652173913043
# Confidence: 0.5
# Lift: 5.75
# =====================================
# Rule: Sharpner -> Eraser
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: Gum -> Pages
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 3.833333333333333
# =====================================
# Rule: Gum -> Scale
# Support: 0.043478260869565216
# Confidence: 0.3333333333333333
# Lift: 7.666666666666666
# =====================================
# Rule: Pages -> Pencil
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Scale -> Pages
# Support: 0.043478260869565216
# Confidence: 0.2
# Lift: 4.6000000000000005
# =====================================
# Rule: Perfume -> Pages
# Support: 0.043478260869565216
# Confidence: 0.25
# Lift: 5.75
# =====================================
# Rule: nan -> Pencil
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 7.666666666666667
# =====================================
# Rule: Scale -> nan
# Support: 0.043478260869565216
# Confidence: 1.0
# Lift: 5.75
# =====================================
