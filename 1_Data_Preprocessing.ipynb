# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#read data from dataset into dataframe
df=pd.read_csv('ds_salaries.csv')

# %%
#display first 4 rows
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# 2                 GB            50               GB            M
# 3                 HN             0               HN            S
# 4                 US            50               US            L

# %%
# get information about dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
# 1.Data Reduction
#Remove/reduce unnecessary arribute from dataframe
subset = df[['work_year','employment_type','job_title','salary','salary_currency','company_location']]
subset.head()
# Out:
#    work_year employment_type                   job_title  salary  \
# 0       2020              FT              Data Scientist   70000
# 1       2020              FT  Machine Learning Scientist  260000
# 2       2020              FT           Big Data Engineer   85000
# 3       2020              FT        Product Data Analyst   20000
# 4       2020              FT   Machine Learning Engineer  150000
#
#   salary_currency company_location
# 0             EUR               DE
# 1             USD               JP
# 2             GBP               GB
# 3             USD               HN
# 4             USD               US

# %%
# 2.Data Cleaning
#find missing values
subset.isnull().sum()
# Out:
# work_year           0
# employment_type     0
# job_title           0
# salary              0
# salary_currency     0
# company_location    0
# dtype: int64

# %%
#define  function for median
def impute_median(series):
  return series.filla(series.median())

# %%
subset2=df[['work_year','job_title','salary','salary_currency','company_location']]
subset2.head()
# Out:
#    work_year                   job_title  salary salary_currency  \
# 0       2020              Data Scientist   70000             EUR
# 1       2020  Machine Learning Scientist  260000             USD
# 2       2020           Big Data Engineer   85000             GBP
# 3       2020        Product Data Analyst   20000             USD
# 4       2020   Machine Learning Engineer  150000             USD
#
#   company_location
# 0               DE
# 1               JP
# 2               GB
# 3               HN
# 4               US

# %%
# 3.Data integration
subset3=pd.merge(subset,subset2,on='company_location')
subset3.head()
# Out:
#    work_year_x employment_type     job_title_x  salary_x salary_currency_x  \
# 0         2020              FT  Data Scientist     70000               EUR
# 1         2020              FT  Data Scientist     70000               EUR
# 2         2020              FT  Data Scientist     70000               EUR
# 3         2020              FT  Data Scientist     70000               EUR
# 4         2020              FT  Data Scientist     70000               EUR
#
#   company_location  work_year_y               job_title_y  salary_y  \
# 0               DE         2020            Data Scientist     70000
# 1               DE         2020  Data Engineering Manager     51999
# 2               DE         2020               ML Engineer     14000
# 3               DE         2020             Data Engineer     48000
# 4               DE         2020  Principal Data Scientist    130000
#
#   salary_currency_y
# 0               EUR
# 1               EUR
# 2               EUR
# 3               EUR
# 4               EUR

# %%
# 4.Data Transformation
subset3.to_excel('ds_salaries.xlsx')
